# %% [markdown]
# <a href="https://colab.research.google.com/github/deschanel11/yolo-customizing/blob/main/yolo_customized_test_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#이제까지는 코랩에서 직접 깃허브의 주소를 clone해서 돌림.
#이번에는 내 구글 드라이브에서 마운트해서 돌려보기.

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#root = '/gdrive/My Drive/yolov5_customized' <-이렇게 하면 마운트가 안 됨... 왜지..?

# %%
# !pip install ruamel.yaml
# Out:
# ...
#      |████████████████████████████████| 109 kB 4.0 MB/s
# ...
#      |████████████████████████████████| 546 kB 29.2 MB/s
# ...

# %%
# !pwd
# Out:
# /content

# %%
cd drive/MyDrive/yolov5_customized
# Out:
# /content/drive/MyDrive/yolov5_customized

# %%
# !pwd
# Out:
# /content/drive/MyDrive/yolov5_customized

# %%
#!python train.py --data data/coco128.yaml --cfg yolov5n.yaml --weights '' --batch-size 16

# %%
#!ln -s '/gdrive/My Drive'/{root.replace('/gdrive/My Drive/', '')}/

# %%
# !python train.py --data data/coco128.yaml --cfg yolov5n.yaml --weights '' --batch-size 16
# Out:
# ...
# train: weights=, cfg=yolov5n.yaml, data=data/coco128.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=300, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: Command 'git fetch && git config --get remote.origin.url' timed out after 5 seconds
# requirements: PyYAML>=5.3.1 not found and is required by YOLOv5, attempting auto-update...
# ...
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...
#
# ...

# %%
# !pip install ruamel.yaml

# %%
# !python train.py --data data/coco128.yaml --cfg yolov5n.yaml --weights '' --batch-size 16
# Out:
# train: weights=, cfg=yolov5n.yaml, data=data/coco128.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=300, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 27 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v6.0-189-gaf00134 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# ...

# %%
# !python detect.py --weights /content/drive/MyDrive/yolov5_customized/runs/train/exp12/weights/best.pt

#/content/drive/MyDrive/yolov5_customized/runs/train/exp12/weights/best.pt
# Out:
# detect: weights=['/content/drive/MyDrive/yolov5_customized/runs/train/exp12/weights/best.pt'], source=data/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-189-gaf00134 torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model Summary: 213 layers, 1817344 parameters, 0 gradients
# image 1/189 /content/drive/MyDrive/yolov5_customized/data/images/IMG_0004.jpeg: 480x640 Done. (0.221s)
# image 2/189 /content/drive/MyDrive/yolov5_customized/data/images/IMG_0007.jpeg: 480x640 1 car, Done. (1.201s)
# image 3/189 /content/drive/MyDrive/yolov5_customized/data/images/IMG_0026.jpeg: 640x480 9 cars, Done. (0.137s)
# ...
